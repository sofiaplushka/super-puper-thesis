# %% [markdown]
# # Tagged corpus final clustering run
#
# Executed Colab bridge artifact for the thesis pipeline.

# %%
import sys, platform, torch
print(environment)
# Out:
# Python: 3.12.13
# Platform: Linux-6.6.122+-x86_64-with-glibc2.35
# Torch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4
# Working directory: /content

# %%
selection
# Out:
# {
#   "feature_set": "hybrid_dense_lexical_dw0.75_lw0.25",
#   "method": "leiden",
#   "metric": "cosine",
#   "params": "k=75;resolution=2.0;seed=7",
#   "k": "75.0",
#   "resolution": "2.0",
#   "seed": "7.0",
#   "rows": "5509.0",
#   "cluster_count": "20.0",
#   "largest_cluster_share": "0.1290615356689054",
#   "noise_share": "0.0",
#   "ari_all": "0.2768398283612387",
#   "ami_all": "0.3771557986073597",
#   "v_measure_all": "0.3870974267318268",
#   "ari_excluding_other": "0.2768398283612387",
#   "ami_excluding_other": "0.3771557986073597",
#   "v_measure_excluding_other": "0.3870974267318268",
#   "ari_single_clear": "0.2768398283612387",
#   "ami_single_clear": "0.3771557986073597",
#   "v_measure_single_clear": "0.3870974267318268",
#   "pairwise_f1_all": "0.3388263088979487",
#   "pairwise_precision_all": "0.3518516488608496",
#   "pairwise_recall_all": "0.3267309233380156",
#   "balanced_score": "0.32302272669239",
#   "n_clusters": "",
#   "error": "",
# ...

# %%
final_metrics
# Out:
# [
#   {
#     "model": "final",
#     "subset": "all",
#     "rows": "5509",
#     "cluster_count": "20",
#     "largest_cluster_share": "0.12906153566890544",
#     "ari": "0.2768398283612387",
#     "ami": "0.3771557986073597",
#     "v_measure": "0.38709742673182684",
#     "pairwise_precision": "0.3518516488608496",
#     "pairwise_recall": "0.3267309233380156",
#     "pairwise_f1": "0.3388263088979487"
#   },
#   {
#     "model": "final",
#     "subset": "excluding_other",
#     "rows": "5509",
#     "cluster_count": "20",
#     "largest_cluster_share": "0.12906153566890544",
#     "ari": "0.2768398283612387",
#     "ami": "0.3771557986073597",
#     "v_measure": "0.38709742673182684",
#     "pairwise_precision": "0.3518516488608496",
#     "pairwise_recall": "0.3267309233380156",
#     "pairwise_f1": "0.3388263088979487"
#   },
#   {
#     "model": "final",
#     "subset": "single_clear_label",
#     "rows": "4921",
#     "cluster_count": "20",
# ...

# %%
before_after
# Out:
# [
#   {
#     "metric": "ari_excluding_other",
#     "old_leiden": "0.19667260190427993",
#     "final": "0.2768398283612387",
#     "delta": "0.08016722645695878"
#   },
#   {
#     "metric": "ami",
#     "old_leiden": "0.30385474060613765",
#     "final": "0.3771557986073597",
#     "delta": "0.07330105800122205"
#   },
#   {
#     "metric": "v_measure_excluding_other",
#     "old_leiden": "0.310894751776334",
#     "final": "0.38709742673182684",
#     "delta": "0.07620267495549282"
#   },
#   {
#     "metric": "pairwise_f1_all",
#     "old_leiden": "0.28461591272768244",
#     "final": "0.3388263088979487",
#     "delta": "0.05421039617026624"
#   },
#   {
#     "metric": "pairwise_precision",
#     "old_leiden": "0.2297050701876919",
#     "final": "0.3518516488608496",
#     "delta": "0.12214657867315767"
#   },
#   {
#     "metric": "pairwise_recall",
#     "old_leiden": "0.37402675757357035",
#     "final": "0.3267309233380156",
#     "delta": "-0.04729583423555472"
#   },
# ...

# %%
generated_artifacts
# Out:
# outputs/figures/umap2d_final.html
# outputs/figures/umap3d_final.html
# outputs/figures/umap2d_final.png
# outputs/figures/umap3d_final.png
# outputs/tables/cluster_final_interpretation_cards.csv
